# %% [markdown]
# # Import the required modules

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import style
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Read Data

# %%
house_data = pd.read_csv('housing.csv')

# %%
house_data.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
house_data.shape
# Out:
# (20640, 10)

# %%
house_data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# # Data Cleaning

# %%
house_data.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
house_data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# ### Droping the columns which are 90% empty

# %%
threshold = len(house_data) * 0.1
threshold
# Out:
# 2064.0

# %%
house_data.dropna(thresh=threshold, axis=1, inplace=True)

# %%
house_data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# # Data Imputation and Manipulation

# %%
# Filling the missing values in total bedrooms columns with the median of that column
# Define a function name impute_median
def impute_median(series):
    return series.fillna(series.median())

# %%
house_data.total_bedrooms = house_data['total_bedrooms'].transform(impute_median)

# %%
# Checking
house_data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
house_data.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
house_data.tail(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20630    -121.32     39.29                11.0       2640.0           505.0
# 20631    -121.40     39.33                15.0       2655.0           493.0
# 20632    -121.45     39.26                15.0       2319.0           416.0
# 20633    -121.53     39.19                27.0       2080.0           412.0
# 20634    -121.56     39.27                28.0       2332.0           395.0
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20630      1257.0       445.0         3.5673            112000.0
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Q. How many people live near ocean? Q. Where does people like to live more?

# %%
# Grouping the data for ocean proximity
grp = house_data.groupby('ocean_proximity')
population = grp['population'].agg(np.mean)
house_age = grp['housing_median_age'].agg(np.mean)
households = grp['households'].agg(np.mean)

print(population)
print(house_age)
print(households)
# Out:
# ocean_proximity
# <1H OCEAN     1520.290499
# INLAND        1391.046252
# ISLAND         668.000000
# NEAR BAY      1230.317467
# NEAR OCEAN    1354.008653
# Name: population, dtype: float64
# ocean_proximity
# <1H OCEAN     29.279225
# INLAND        24.271867
# ISLAND        42.400000
# NEAR BAY      37.730131
# NEAR OCEAN    29.347254
# Name: housing_median_age, dtype: float64
# ocean_proximity
# <1H OCEAN     517.744965
# INLAND        477.447565
# ISLAND        276.600000
# NEAR BAY      488.616157
# NEAR OCEAN    501.244545
# Name: households, dtype: float64

# %%
plt.figure(figsize=(8,3))
plt.plot(population, 'ro', color='g')
plt.title('Population Graph')
plt.grid(True)
plt.show()

# %% [markdown]
# #### As we can clearly see that people are less tends to live on an island.

# %% [markdown]
# ### Q. Plot a graph to show the age of houses.

# %%
plt.figure(figsize=(8,3))
plt.plot(house_age, 'ro', color='b')
plt.title('House Age Graph')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Q. How many people live in old houses?

# %%
plt.figure(figsize=(8,3))
plt.plot(house_age, population, 'ro', color='b')
plt.title('House Age vs. Population')
plt.xlabel('Age of house')
plt.ylabel('Human population')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(16,7))

plt.plot(population, color='b', label='Population')
plt.plot(households, color='r', label='Houlseholds')
plt.legend()

plt.grid(True)
plt.show()

# %% [markdown]
# ### Q. Where is highest number of households?

# %%
style.use('ggplot')
plt.figure(figsize=(8,3))
plt.plot(households, 'ro', color='r')
plt.show()
